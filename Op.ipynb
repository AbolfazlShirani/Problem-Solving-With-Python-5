# %%
a = 11
b = 85
c = 99
d = 1

# %%
a and b
# Out:
# 85

# %%
a and c
# Out:
# 99

# %%
a and d
# Out:
# 1

# %%
b and a
# Out:
# 11

# %%
b and c
# Out:
# 99

# %%
b and d
# Out:
# 1

# %%
c and a
# Out:
# 11

# %%
c and b
# Out:
# 85

# %%
c and d
# Out:
# 1

# %%
a and ''
# Out:
# ''

# %%
a or b
# Out:
# 11

# %%
a or c
# Out:
# 11

# %%
a or d
# Out:
# 11

# %%
b or a
# Out:
# 85

# %%
b or c
# Out:
# 85

# %%
b or d
# Out:
# 85

# %%
c or a
# Out:
# 99

# %%
c or b
# Out:
# 99

# %%
c or d
# Out:
# 99

# %%
a or ""
# Out:
# 11

# %%
not a
# Out:
# False

# %%
not b
# Out:
# False

# %%
not c
# Out:
# False

# %%
not d
# Out:
# False

# %%
not ''
# Out:
# True

# %%
not 0
# Out:
# True

# %%
not "aboli"
# Out:
# False

# %%
not 5
# Out:
# False

# %%
not 1.5
# Out:
# False

# %%
a+b
# Out:
# 96

# %%
a+a
# Out:
# 22

# %%
a+c
# Out:
# 110

# %%
a+d
# Out:
# 12

# %%
d+b
# Out:
# 86

# %%
c+d
# Out:
# 100

# %%
a-b
# Out:
# -74

# %%
b-c
# Out:
# -14

# %%
c-d
# Out:
# 98

# %%
a-d
# Out:
# 10

# %%
d-b
# Out:
# -84

# %%
a*b
# Out:
# 935

# %%
a*c
# Out:
# 1089

# %%
a*a
# Out:
# 121

# %%
a*d
# Out:
# 11

# %%
b*b
# Out:
# 7225

# %%
a/b
# Out:
# 0.12941176470588237

# %%
b/d
# Out:
# 85.0

# %%
c/d
# Out:
# 99.0

# %%
d/b
# Out:
# 0.011764705882352941

# %%
a//b
# Out:
# 0

# %%
a//d
# Out:
# 11

# %%
d//b
# Out:
# 0

# %%
a%d
# Out:
# 0

# %%
a%c
# Out:
# 11

# %%
a%a
# Out:
# 0

# %%
a>b
# Out:
# False

# %%
a<d
# Out:
# False

# %%
a>c
# Out:
# False

# %%
a<b
# Out:
# True

# %%
a>d
# Out:
# True

# %%
a!=b
# Out:
# True

# %%
b == d
# Out:
# False

# %%
a>=b<d
# Out:
# False

# %%
a!=b>d
# Out:
# False

# %%
d>b!=a
# Out:
# False

# %%
a<=d!=a>b
# Out:
# False
